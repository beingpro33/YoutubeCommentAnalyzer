# %%
from googleapiclient.discovery import build
import pandas as pd

import pandas as pd
import re
import emoji
from langdetect import detect, DetectorFactory
from langdetect.lang_detect_exception import LangDetectException
from googletrans import Translator
from textblob import TextBlob
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import seaborn as sns
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from collections import Counter
import nltk

# import seaborn as sns

# %%
# Download necessary NLTK data files
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\abhis\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\abhis\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\abhis\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Set seed for consistent language detection results
DetectorFactory.seed = 0

# %%
api_key = 'AIzaSyC9JU79CqHoZeWinCI6qe2xzrg64jbeGro'
channel_id = 'UCM5lnK0WJyzr6JEwkoT5VUw'

youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# ## Function to get channel statistics

# %%
def get_channel_stats(youtube, channel_id):
  
  request = youtube.channels().list(
    part = 'snippet, contentDetails, statistics',
    id = channel_id
  )

  response = request.execute()

  if 'items' not in response or len(response['items']) == 0:
        return {'error': 'Channel not found or invalid channel ID'}


  data = dict(Channel_name = response['items'][0]['snippet']['title'],
              Subscribers = response['items'][0]['statistics']['subscriberCount'],
              Views = response['items'][0]['statistics']['viewCount'],
              Total_videos = response['items'][0]['statistics']['videoCount'])
  
  return data

# %%
get_channel_stats(youtube, channel_id)
# Out:
# {'Channel_name': 'RS Live',
#  'Subscribers': '259000',
#  'Views': '81632803',
#  'Total_videos': '1052'}

# %%
# def fetch_comments(youtube, video_id):
    
#     comments = []
#     request = youtube.commentThreads().list(
#         part="snippet",
#         videoId=video_id,
#         maxResults=100
#     )

#     while request:
#         response = request.execute()
        
#         for item in response['items']:
#             comment = item['snippet']['topLevelComment']['snippet']
#             comments.append([
#                 comment['authorDisplayName'],
#                 comment['publishedAt'],
#                 comment['updatedAt'],
#                 comment['likeCount'],
#                 comment['textDisplay']
#             ])
        
#         # Check if there's a next page of comments
#         request = youtube.commentThreads().list_next(request, response)
    
#     return comments


#---------------
#just text
#---------------


# def fetch_comments(youtube, video_id):
    
#     comments = []
#     request = youtube.commentThreads().list(
#         part="snippet",
#         videoId=video_id,
#         maxResults=100
#     )

#     while request:
#         response = request.execute()
        
#         for item in response['items']:
#             comment = item['snippet']['topLevelComment']['snippet']
#             comments.append([comment['textDisplay'],
#                             comment['authorDisplayName']])
        
#         # Check if there's a next page of comments
#         request = youtube.commentThreads().list_next(request, response)
    
#     return comments



#---------------
#Text with author name and serial number
#---------------

def fetch_comments(youtube, video_id):
    comments = []
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=100
    )

    serial_number = 1

    while request:
        response = request.execute()
        
        for item in response['items']:
            comment = item['snippet']['topLevelComment']['snippet']
            comments.append([serial_number, comment['textDisplay'], comment['authorDisplayName']])
            serial_number += 1
        
        # Check if there's a next page of comments
        request = youtube.commentThreads().list_next(request, response)
    
    return comments

# %%
def print_comments(comments):
    
    for comment in comments:
        print(comment)
        print("-" * 40)  # Separator between comments

# %%
def save_comments_to_csv(comments, csv_filename):
    # Create a DataFrame from the comments list
    df = pd.DataFrame(comments, columns=['Serial Number', 'Comment', 'Author'])
    
    # Save the DataFrame to a CSV file
    df.to_csv(csv_filename, index=False)
    print(f"Comments have been saved to {csv_filename}")

# %%
video_id = 'TSZbuIqzi3w'
csv_filename = 'youtube_comments.csv'

# Fetch comments
comments = fetch_comments(youtube, video_id)

# Print comments
print_comments(comments)

# Save comments to CSV
save_comments_to_csv(comments, csv_filename)
# Out:
# [1, 'Nice video', '@ashutoshas5819']
# ----------------------------------------
# [2, 'Bihta airport ka bhi progress report dikhana hai bhai', '@atikwarsi4819']
# ----------------------------------------
# [3, 'Bhai patna bachao tree lagao video me per ki bahoot kami hai', '@CTOJ1']
# ----------------------------------------
# [4, '10 sal se metro banna raha hai Gujarat ke andar 2 sal ke andar metro start ho gai hai', '@mrmudassiralam3935']
# ----------------------------------------
# [5, '❤❤❤❤❤❤❤🎉🎉🎉🎉', '@Rahulvolsg2655']
# ----------------------------------------
# [6, 'need part 2', '@thorin999']
# ----------------------------------------
# [7, 'Hm Ashok rajpath se gujarte the lekin hm nhi dekh pate the matro k kam apne kuch minut me dikha diya thanks sir', '@alifa7423']
# ----------------------------------------
# [8, 'Jai bihari ❤', '@Sonalikadaknathchickenlover']
# ----------------------------------------
# [9, 'Excellent presentation on Patna Metro', '@pijushkumarroy4912']
# ----------------------------------------
# [10, 'kitna time lg skta h sb kuch complete hone me????', '@Ejaz_Ali']
# ----------------------------------------
# [11, 'Delhi metro best performance', '@muhammadniralesheikh1625']
# ----------------------------------------
# [12, '<a href="https://www.youtube.com/watch?v=TSZbuIqzi3w&amp;t=508">8:28</a> ulta bol diya bro', '@rajnishkushx']
# ----------------------------------------
# [13, 'Kon kon si companies work kr rhi hai yaha #', '@Ajaysh207']
# ----------------------------------------
# [14, 'Which is the starting music??', '@KaradenizliMacerasi']
# ----------------------------------------
# [15, '❤❤❤❤', '@nabinthakur3611']
# ----------------------------------------
# [16, 'Malahi pakri station is perpendicular to the line , and 50 metre north than the pointed point  .', '@EdookationHub']
# ----------------------------------------
# [17, 'Abhi aur 20 saal lagaga', '@1amitjha']
# ----------------------------------------
# [18, 'Your videography and representation is awesome. ❤', '@animaqaar']
# ----------------------------------------
# [19, 'KYA AAP YOUTUBER HO<br>AAPAKA NUMBER MILEGA', '@vaishnavifibreworkshop']
# ----------------------------------------
# [20, 'Dhaasu video quality... Mjaaa aa gya', '@Sharmascorner']
# ----------------------------------------
# [21, 'its khemnichak not khemkichak', '@sweshanksharma4107']
# ----------------------------------------
# [22, 'Aane wale waqt me India  ka sabse khubsurat  city hoga ye kitna mast view hai😊❤ samtal jamin par basaya gaya sahar bagal me ganga ka najara waw this is Amazing 😍❤😘🇮🇳', '@Ajam359']
# ----------------------------------------
# [23, 'Bhai video bahut acha hai bs video quality aur bdhiya chahiye tha ❤', '@shireeshnikumbh001']
# ----------------------------------------
# [24, 'Pls share the station names', '@bikashkumarsingh3035']
# ----------------------------------------
# [25, 'Work is very slow,even 1st phase is not completed', '@RakeshKumar-mv8kr']
# ----------------------------------------
# [26, 'Kb tk taiyar ho jayega', '@GurjeetSingh-fu7gt']
# ----------------------------------------
# [27, 'Patna metro ke karan barbad ho gya hai.....kitne shopkeeper ka ghar nahe chal paa raha hai.......government has done blunder ....major blunder.....without planning  for shopkeepers they have made the project.......and after.metro what will happen to rakshaw wala and auto wala......as if apna bihar top ten growinh state.mai haiiiii........', '@Beautybrainsvlogs']
# ----------------------------------------
# [28, 'Kab tak pura ban jayega', '@adityaaman.20']
# ----------------------------------------
# [29, 'जब से ये पटना मेट्रो बन रहा उससे पीछे काम चालू यूपी के कितने शहर में मेट्रो चालू गया है<br>बिहार में इस स्पीड से ही काम होता है', '@ayamsingh4219']
# ----------------------------------------
# [30, 'Thanku bhiaa😊😊', '@sujitshaw7106']
# ----------------------------------------
# [31, 'Metro should be underground', '@yourstrulytk12worldaffairs']
# ----------------------------------------
# [32, 'Bhai ghaighat ke idhar koi station nhi banaya jayega kya ya AShok rajpath me', '@AmanveerkiranSingh']
# ----------------------------------------
# [33, 'thanks sir', '@bhevinkrishnamurthy9657']
# ----------------------------------------
# [34, 'There should be more detail in the narration of the story. video Was good', '@Mehndiartmala']
# ----------------------------------------
# [35, 'At <a href="https://www.youtube.com/watch?v=TSZbuIqzi3w&amp;t=612">10:12</a> &quot;Rajendra Nagar Junction&quot; ke jagha &quot;Rajendra Nagar Terminal&quot; hoga', '@rishavraj0962']
# ----------------------------------------
# [36, 'Saguna more nahi dikhaya', '@santoshchoudhary2004']
# ----------------------------------------
# [37, 'Okay', '@prakaashguptaaofficial2599']
# ----------------------------------------
# [38, 'Bhai me 2017 me gaya tha pillar tab bhi ban chuka tha ...avi tak nahi bana ...sach me bihar mahan h ...manna padega bihar k neta bahut hi slow h  decision lene me ....aur bolu gujrat bahut fast h isiliye jaldi jaldi sari companiya wahi chali jati kyuki sarkar waha ki support karti taki hnko paisa banta rahe....bhai agar bihar chahiye develop to out of box sochna padega ...aur janta ka sath hona jaruri h ...', '@raviprasad7654']
# ----------------------------------------
# [39, 'Jharkhand me bhi  metro ajata yaar<br>Sir is baat ko government tak pahuncha sakte h to please pahuchaye.', '@Abhishek_is_live']
# ----------------------------------------
# [40, 'Patna me chor log rahta hai', '@rehan4451']
# ----------------------------------------
# [41, 'Khemkichak ni khemnichak h bro', '@shubhamsingh2414']
# ----------------------------------------
# [42, 'Bhai last me Traffic police ka Furti dekho Kisi Govt official Car ko dekh ke <a href="https://www.youtube.com/watch?v=TSZbuIqzi3w&amp;t=877">14:37</a>', '@himanshunehaleducation']
# ----------------------------------------
# [43, 'Waah Bhai superb Roshan bro', '@khushbuthakur4172']
# ----------------------------------------
# [44, 'Good Work bro', '@Dark_Horse_Guddu']
# ----------------------------------------
# [45, 'Bhai yaha ka construction dekh kar dar lagta hai kab collapse ho jaye😢', '@AmanKumar-zs8yl']
# ----------------------------------------
# [46, 'adhura video tha ye wala', '@Mukeshkumar-it8lj']
# ----------------------------------------
# [47, 'Nice video', '@travellingparrot5975']
# ----------------------------------------
# [48, 'Expecting that Patna be the 2nd East India developed city in near future.... Love from Kolkata 💌', '@gishan.19']
# ----------------------------------------
# [49, '<a href="https://www.youtube.com/watch?v=TSZbuIqzi3w&amp;t=77">1:17</a> <br>starts from here', '@drax588']
# ----------------------------------------
# [50, 'Dekhna bhai chalne se pahle hi na gir jay love from m.p.', '@jugarofmaths3637']
# ----------------------------------------
# [51, 'Kahan se kahan tak metro caloga', '@chotudas700']
# ----------------------------------------
# [52, 'Kab tak girega', '@Amritbhajaan']
# ----------------------------------------
# [53, 'pmrc start ❤️\u200d🔥', '@Aditya_brain_booster']
# ----------------------------------------
# [54, 'Beta', '@ManitaYadav-bg9xk']
# ----------------------------------------
# [55, 'Beta sabse barri yojna kya hai', '@ManitaYadav-bg9xk']
# ----------------------------------------
# [56, 'खेमनी चक है सर', '@VikashKumar-to1mm']
# ----------------------------------------
# [57, 'thanks for update', '@comfort-l8m']
# ----------------------------------------
# [58, 'Thanks to NDA and JDU for this good project', '@dhananjaykumarsingh238']
# ----------------------------------------
# [59, 'Sasura kab banega <br>Patna metro kahi Delhi metro na ban Jaye', '@TurtleGaming.']
# ----------------------------------------
# [60, 'Nice video', '@ConstructionErzeshankhan']
# ----------------------------------------
# [61, 'Dekho kahi bridge k jaise gir na jaye', '@ashutiwari5312']
# ----------------------------------------
# [62, 'Thnx bhaiya itni jaankari dene ke liye😊', '@YouTubehandle962']
# ----------------------------------------
# [63, '👌👌❤', '@rohitmax827']
# ----------------------------------------
# [64, 'Nice work', '@Theindianvlogger1']
# ----------------------------------------
# [65, 'is janam mein sayad ban jaayeee', '@keshavrishu367']
# ----------------------------------------
# [66, 'Pura cover kyu nhi Kiya', '@watchdogs467']
# ----------------------------------------
# [67, '5 saal lagega PATNA me metro banane me aur roads ki halat toh itni gandi h ke kya hi bolu... <br>Jagha jagha gande naliya full of pollution <br>Bht Ganda jagha Patna <br>Rever recommended to visit patna', '@bePrem79']
# ----------------------------------------
# [68, 'After JagjivanRam and Jaiprakash Narayan, JeetanRam PaltuRam ki kripa se development ho rahaa hai Bihar mein', '@rakeshranjan9295']
# ----------------------------------------
# [69, 'Good video update......After JagjivanRam ,JeetanRam PaltuRam ki kripa se development ho rahaa hai Bihar mein', '@rakeshranjan9295']
# ----------------------------------------
# [70, 'Metro Good Fecility&#39;s', '@srinusrinivas7880']
# ----------------------------------------
# [71, 'I am rating 5 because your presentation is very good', '@AyubKhan-vl6yn']
# ----------------------------------------
# [72, 'Bhaiya kab tak start hoga', '@HimanshuKumar-or3ed']
# ----------------------------------------
# [73, 'Khane pine ke alawa apke vlog k through kuch bht acha dekhne ko mila.. thanks ❤', '@sachinprabhakar298']
# ----------------------------------------
# [74, '❤❤', '@sachinprabhakar298']
# ----------------------------------------
# [75, 'Bhout khub ❤❤❤❤❤', '@chandanrai5919']
# ----------------------------------------
# [76, 'खेमनी चक😂', '@dj__BABA575']
# ----------------------------------------
# [77, 'Bihar ka capital hai na Patna , Capital ka hi aisa haal to baki place ka to kya hi bolu😂 . Ye Nitish dogla capital ko bhi develop nahi kar paaya itne saalo se 😂<br>Abhi minimum 10 saal lagega metro banne me ya fir ye Nitish dogla raha to aur bhi jyada', '@Anonymous-on1fw']
# ----------------------------------------
# [78, 'Bakhtiyarpur se Rajauli 4 lane road ka update karo', '@AnkitKumar.76']
# ----------------------------------------
# [79, 'Nice', '@amitkumar-ws7mo']
# ----------------------------------------
# [80, 'Dhyan rakhna bro Kahi iss metro ko hin na chura le jaye bihar balo ne🤣🤣🤣', '@Vibesofalok']
# ----------------------------------------
# [81, 'Paan stains everywhere 😂😂😂😂😂', '@booksquotes948']
# ----------------------------------------
# [82, 'I request all concerned members, kindly initiate eight lane express road in Patna asap.', '@Time-heals_everything9']
# ----------------------------------------
# [83, 'हम हैं patna balla', '@raushankukuday5k954']
# ----------------------------------------
# [84, 'Your video is the best ever', '@Manishkumar-lu9vu']
# ----------------------------------------
# [85, 'बहुत अच्छा लगा भाई 🎉<br><br>क्या आप बतिएगा किस ड्रोन की सहायता से आपने इतना अच्छा वीडियो बनाया है।', '@apnatime6665']
# ----------------------------------------
# [86, 'Mere Bihar ke sabhi brother sister ko mera humble request hai iss baar vote BJP candidate ko do jo deserve karta hai. Jo Bihar ko develop karega. Bihar mein progress karega. Aab se caste dekhke vote mat do please. Lots of love and huge respect to Bihar and Bihari people from Delhi. ❤❤<br>Jai Shree Ram and Jai Hind 🚩🚩🙏🙏', '@robb2024']
# ----------------------------------------
# [87, 'Very slow city', '@mahboobalam2644']
# ----------------------------------------
# [88, 'Nice video', '@iftekharahsan5513']
# ----------------------------------------
# [89, 'Bihar me Road 2 lane se jyada nahi bun raha hai,,,Aaj dusre state me 6 lane aur 8 lane par kaam ho raha hai jo purana road hai uska chaurikaran ho raha hai,,Lekin Bihar Sarkar kuchh nahi kar raha hai,,Patna west ka rural area ka road ka bahut bura haal hai,,Law and order finish hai,,,,Nitish sarkar sabse bekar..', '@AftabEqbal-c2k']
# ----------------------------------------
# [90, 'Saguna more ka bhi dikh dijiye', '@AjeetChaurasiya.']
# ----------------------------------------
# [91, 'Good initiative Bhaiya', '@shyamyadav7570']
# ----------------------------------------
# [92, 'Jai Ma Bharati  🇮🇳🔱🚩✌️', '@sayanmandal1936']
# ----------------------------------------
# [93, 'Indore our Bhopal metro ka update', '@mohammadIrfan-nf1ny']
# ----------------------------------------
# [94, 'Awesome Love u Patna ❤From Patna 😊', '@HealthCareHomoeoPharmacy']
# ----------------------------------------
# [95, 'But boring road, belly road ,pattliputra yye sab kaha gaya bhai', '@sachinsingh8508']
# ----------------------------------------
# [96, 'Begusarai meto banao', '@Thakurvikas']
# ----------------------------------------
# [97, 'Bihar me sirf patna ka vikash ho rha hai baki zilla ko toh sirf loota ja rha hai😂', '@jugeshkumar9228']
# ----------------------------------------
# [98, 'Nice &amp; detailed video truly', '@smallworld1427']
# ----------------------------------------
# [99, 'Do not show fake video,', '@sonalisingh6308']
# ----------------------------------------
# [100, 'Bihar ek developing state hai. Ab samay aa gaya hai bihar mein bohot sare industries lane ka👍', '@Truthhurts321']
# ----------------------------------------
# [101, 'Garib Bihari ko fir dokha', '@AzadKhan-wx1ht']
# ----------------------------------------
# [102, 'Bihar me bahar hai😂😂😂', '@shailendrasingh007U']
# ----------------------------------------
# [103, 'Drone  shoot ke liye kinse permission liye the bhaiya.?', '@aryaeducation6987']
# ----------------------------------------
# [104, 'जय बिहार, नितीश कुमार', '@Surajkiduniya8032']
# ----------------------------------------
# [105, 'Great work sir but i want to correct you on malahi pakri metro station location as it was supposed to build 100m ahead of where you are indicated. All the best🎉', '@ehteshamnawaz589']
# ----------------------------------------
# [106, 'Ur voice 😂😂😂😂😂😂😂 bihhhhaaarrrr', '@brunokumar7511']
# ----------------------------------------
# [107, 'Nitish Kumar is doing increadble work 🙏🙏🙏🙏🙏', '@sonumahato588']
# ----------------------------------------
# [108, 'Nice my City is developing 👌👌👌👌👌', '@sonumahato588']
# ----------------------------------------
# [109, 'Thanks 🎉🎉', '@kumar_dkyt']
# ----------------------------------------
# [110, 'Allah hu akbar wale like kare', '@BhgwaTrapAwarenesNoori']
# ----------------------------------------
# [111, 'Modi hai to mumkin hai.', '@virenderaggarwal3935']
# ----------------------------------------
# [112, 'Metro in front of agriculture field!!<br>Just Bihar things.', '@adithya8660']
# ----------------------------------------
# [113, 'aarr mithapur ka nai dekhaa tum', '@Gonda169']
# ----------------------------------------
# [114, 'I request to all bihari  vote those candidate  they bring some development', '@invisible9828']
# ----------------------------------------
# [115, 'Your video always make us nostalgic', '@vibkiotech5235']
# ----------------------------------------
# [116, 'Thanks for the patna metro updates and amazing views from your drone shots😊', '@RohitSingh-ku4hb']
# ----------------------------------------
# [117, 'Baki development kha hai', '@SangitaSingh-lh2bi']
# ----------------------------------------
# [118, 'Exceptional video,ghar baithay baithay hi vikas sheel Bihar ki tasveer dikha di apne,bahut saara aabhar aapko❤❤❤', '@amanprakash7692']
# ----------------------------------------
# [119, 'बहुत अच्छा लागा बिहार का विकास कार्य देख कर. आप के सभी विडिओ कि तरह यह भी विडिओ बहुत ही सुंदर 👌👌😊😊लगा 🎉🎉', '@dipakvanikar6254']
# ----------------------------------------
# [120, 'आपका वीडियो 100% परफेक्शन वाला होता है जबरदस्त', '@nitishdivyansharti3495']
# ----------------------------------------
# [121, 'Bihar ka transport mat boliye sirf Patna ka kah sakte hai', '@swarajsaurabh']
# ----------------------------------------
# [122, 'Ugliest city ever.....', '@JitzyJT']
# ----------------------------------------
# [123, 'Patna looks like some undeveloped African country..', '@AkashSingh-nf5ey']
# ----------------------------------------
# [124, 'wah bhai aapka tarika bahut shandar hai infra update dene ka..', '@rnpandit604']
# ----------------------------------------
# [125, 'Thanks so much 🙏', '@premprabhakar805']
# ----------------------------------------
# [126, 'Modi ji ne bhut acha kaam kr rhe hai ❤', '@jitendratiwari6721']
# ----------------------------------------
# [127, 'Patna mahanagar ka metro project ka update dene ke liye apka <br><br>Bahut shukriya bhaiya 🙏🙏', '@nikhilaryanstudio7917']
# ----------------------------------------
# [128, 'Hello brother apka to animation ke jariye Patna matro ka work in progress dikhaya maza aa gaya', '@pravins4957']
# ----------------------------------------
# [129, 'Awesome Drone view ❣️❣️❣️', '@Mech.Engineering_Student']
# ----------------------------------------
# [130, 'हमारे राजस्थान के अशोक गहलोत जी ने अपने दम पर जयपुर मेट्रो 2012-2015 में लोंच कर दी थी, केंद्र सरकार का एक पैसा भी नहीं लगा था,  <br>अब दुसरे फेज में जरूर 20% पैसा केंद्र सरकार लगा है,', '@चतुररामलिंगम-भ8ज']
# ----------------------------------------
# [131, 'Rajgir cricket stadium update??', '@RohitRaj-we5hs']
# ----------------------------------------
# [132, 'भाई आप गुजरात आना बड़दा का video बनाने ❤', '@kammugamar']
# ----------------------------------------
# [133, 'Very nice 👍🙏', '@rajnishkamboj6596']
# ----------------------------------------
# [134, 'Correction-Rajendra nagar terminal  hai', '@md.saadiqashraf762']
# ----------------------------------------
# [135, 'Aap ka tahe dil se sukriya <br>Hamare bihar ko explore karne ke lia or yaha ke project ko desh duniya tak pahuchane ke lia', '@localinfobyts']
# ----------------------------------------
# [136, 'Rajgir ka stadium ka bhi update de dijiye 😊😊', '@Vivekkumar-dc7xc']
# ----------------------------------------
# [137, 'Indian cities should adopt the Barcelona approach of keeping a central courtyard when constructing apartments. That way, there is a lot of space for pedestrian foot traffic and multi-use spaces. These small buildings in Tier 2 cities look very ugly.', '@wassuphomies263']
# ----------------------------------------
# [138, 'People say Bihar is a very green ( plant, yrees) state but Patna looks like a new desert in rhe making. I see the same across the stupid Hindi belt. People are desertification every region by not planting and nurturing greenery.', '@atokimruk937']
# ----------------------------------------
# [139, 'Brother you missed 2 main stations &quot;Moinul Haq Station &amp; Patna University Station&quot;', '@nomadicbihari5759']
# ----------------------------------------
# [140, 'Jai hind bhai', '@Nvin.Tehlan.Comdey']
# ----------------------------------------
# [141, 'Nice ❤', '@SrikantKumar-r8c']
# ----------------------------------------
# [142, 'Jai hind sir', '@anandaadhikary5462']
# ----------------------------------------
# [143, 'Bhai..<br>Ghazipur <del>Ballia</del> Majhi ghat Greenfield expressway ki update do..', '@Nikhil_Panday']
# ----------------------------------------
# [144, 'Bhai shooting bahut hi Achcha hai Patna metro ka 😮❤❤❤', '@amitbhagat1076']
# ----------------------------------------
# [145, 'Good 🎉 welcome new Railway metro rail project', '@kameswarYouTubeExpress']
# ----------------------------------------
# [146, 'Patna looks like a big concrete jungle.', '@prakhardubey2356']
# ----------------------------------------
# [147, 'I live in bhootnath', '@PAWANKUMAR-yh7rh']
# ----------------------------------------
# [148, 'Thnks..❤', '@PAWANKUMAR-yh7rh']
# ----------------------------------------
# [149, 'AIIMS side nhi ayga kya metro 🚇😢', '@street_shifter_shivam']
# ----------------------------------------
# [150, 'Waiting for your next vedio on bihar', '@sahil-E-11']
# ----------------------------------------
# [151, 'Jai bihar❤', '@defenceindiaseries9448']
# ----------------------------------------
# [152, 'Surat metro', '@ahirjenil6694']
# ----------------------------------------
# [153, 'Delhi dehradun expressway ki update KB TK aayegi', '@legalresearch2740']
# ----------------------------------------
# [154, 'Ancient Bihar 🗿<br>Current Bihar 🤮', '@Kp-pd2jc']
# ----------------------------------------
# [155, 'Ballia link expressway ka update de', '@pushpenderbharti2616']
# ----------------------------------------
# [156, 'Nice work of you and your team', '@kartikranjan8193']
# ----------------------------------------
# [157, '<a href="https://www.youtube.com/watch?v=TSZbuIqzi3w&amp;t=635">10:35</a> Delhi Metro 😅 or Patna metro', '@AkashKumarSingh-lt3vi']
# ----------------------------------------
# [158, 'Osm', '@AmitSingh-sv7wk']
# ----------------------------------------
# [159, 'Patna metro work fast hona chahiye', '@fahimshaikh8801']
# ----------------------------------------
# [160, 'If possible go to Jharkhand as well. Project suggestions :-<br>1. 6 Laning of NH 18 which is part of golden quadrilateral and also includes viaduct like in Barhi.<br>2. Ormanjhi Gola Jainamore expressway which is also called Ranchi Bokaro expressway<br>3. Bridge on Ganga river in Sahebganj', '@IntrovertBoyz']
# ----------------------------------------
# [161, 'Bhai dhekna kahi bride piller na gir jaye apne aap corrupt politicians se..', '@sandeep-Maurya.']
# ----------------------------------------
# [162, 'Nice video 👏👏 detail coverage❤', '@mandarlimaye6027']
# ----------------------------------------
# [163, 'Maharashtra ke paison se Bihar ka train ban rha hai😢', '@ku5285']
# ----------------------------------------
# [164, 'One of the best YouTuber ❤.  Aap sbse achaa update dete ho. So pleasant to watch.', '@coolRajnishkr']
# ----------------------------------------
# [165, 'EDFC ka bhi update <br>Kaha tak kam hua abhi', '@SarveshSingh-gk6ue']
# ----------------------------------------
# [166, 'Hi rajan bhaiya <br>Kaise ho<br>Aate samay Ganga express ka bhi full update de dejia <br>Full update dejiaga', '@SarveshSingh-gk6ue']
# ----------------------------------------
# [167, '👍👍👍👍👍', '@nitinjha3906']
# ----------------------------------------
# [168, 'Welcome to bihar I am from motihari', '@nitishkumarnk1008']
# ----------------------------------------
# [169, 'Bjp', '@travellerclinto470']
# ----------------------------------------
# [170, 'Agartala', '@travellerclinto470']
# ----------------------------------------
# [171, 'PMCH ka bhi update dijiyega sar', '@DeepakKumar-re6no']
# ----------------------------------------
# [172, 'मुझे लगता है पटना मेट्रो और बुलेट ट्रेन का शुभारम एक साथ ही होगा😊', '@general559']
# ----------------------------------------
# [173, 'Aapke hisab ae pehele kiss city mein metro aayegi indorw , bhopal , patna ya surat ?', '@aradhyajain9783']
# ----------------------------------------
# [174, 'Chhapra double decker Bridge ka de dijiye', '@DeepakKumar-re6no']
# ----------------------------------------
# [175, 'Worst city to live in india', '@shashanksingh4510']
# ----------------------------------------
# [176, 'Sar Rajgir cricket stadium ka update dijiye na', '@DeepakKumar-re6no']
# ----------------------------------------
# [177, 'Thank you ♥', '@princemyself1212']
# ----------------------------------------
# [178, 'Explained better than all the local youtubers of bihar', '@UK-xv1db']
# ----------------------------------------
# [179, 'Bhai kitni bar bolu haryana orbital rail carridor pe update do', '@ritikbainslasingh1292']
# ----------------------------------------
# [180, 'Vedio me ek information  aap galat bataya h khenichak metro station  se red line straight  jayega and blue  line turn lega...mai aap ka regular  viewer  hun aap ka vedio shandar hota h', '@hikervlogs9586']
# ----------------------------------------
# [181, 'Full metro alignment ka work process batana tha wose yeh bs 25% work hi cover Kiya hai ish update.', '@sidorbuddha']
# ----------------------------------------
# [182, 'brother you left the bailey Road area', '@shubhyadav8825']
# ----------------------------------------
# [183, 'Chapra double decker flyover', '@sikandarkumarsah4343']
# ----------------------------------------
# [184, 'Love from bihar❤', '@sagarsah1654']
# ----------------------------------------
# [185, 'Wrong 1st TBM USED IN MOINUL HAQUE STADIUM IN PATNA METRO,NOT GANDHI MAIDAN.', '@FarhanAhmed-wb6nh']
# ----------------------------------------
# [186, 'Ek baar marine drive ka full video or pmch ka bhi bana digiyega and NIT new campus', '@SanjayKumar-e8f7p']
# ----------------------------------------
# [187, 'One of the best video of bihar infrastructure.thanks bhaiya', '@SanjayKumar-e8f7p']
# ----------------------------------------
# [188, 'Nice update.', '@ishantkumar-kw2tt']
# ----------------------------------------
# [189, 'drones shots bahot achhi hoti aapki.. 🌟', '@Aniket.kumar135']
# ----------------------------------------
# [190, 'Bhai poore kolkata metro project cover Karo na...aapse hee ummed hai bas uske coverage kee', '@rajataggarwal262']
# ----------------------------------------
# [191, 'cool', '@Dev-Phantom']
# ----------------------------------------
# [192, 'अद्भुत नजारा... ❤❤ छपरा में \xa0डबल डेकर फ्लाईओव भी दिखाएं सर...', '@plot721']
# ----------------------------------------
# [193, 'Rrts update sir', '@khushibhatia8553']
# ----------------------------------------
# [194, 'Our cities are so unorganised. Jisko jaha marzi waha apna ghar banaya h..but when I see European cities👌👌', '@ankitsingh0941']
# ----------------------------------------
# [195, 'Rajauli -bakhtiyarpur four lane ,🎉 simaria ghat,Rajgir sports stadium ka v update de🎉', '@SvStudypoint-ht8hp']
# ----------------------------------------
# [196, 'Sir pmch ko v dikhaye jo naya construction 🏗️ ho rha h', '@SvStudypoint-ht8hp']
# ----------------------------------------
# [197, 'Thanks for coming to bihar bhai......bhai kachidargha bidupur bridge , patna marine drive , new gandhi sethu update please bhai..', '@VijayKumar-so1wx']
# ----------------------------------------
# [198, 'City looks so dirty and unplanned', '@randomnerd4444']
# ----------------------------------------
# [199, 'Bhai ji delhi metro ki bhi update dedo boht time hogya h pink ot magenta line ki', '@thestranger9247']
# ----------------------------------------
# [200, 'Aapka samjhane ka tarika 1 no. hai sir', '@kingofadventures1122']
# ----------------------------------------
# [201, 'rewa airport plzzzz', '@Krishna-zm7yx']
# ----------------------------------------
# [202, 'Superb amazing update of patna metro', '@kingofadventures1122']
# ----------------------------------------
# [203, 'Why Patna is looking so underdeveloped?  What could be the reason?', '@saksham2525']
# ----------------------------------------
# [204, 'Welcome to the Bihar 🎉', '@SurajKumar-mr3ur']
# ----------------------------------------
# [205, 'Bhaiya ho sake to rrts ka ek aur update jald kardo Modinagar wale section per,sunne me aa rha hai Modinagar North tak inaugurate karne ka plan h 10 March tak.', '@anandtyagi248']
# ----------------------------------------
# [206, 'Recently PMCH new building is inaugurated, I think you forgot to mention.', '@kamaladitya52']
# ----------------------------------------
# [207, 'A great video for that information get soon metro in a Indian city and very happy to all area connected infrastructure boom for thanks you Rajan Sir', '@Aryan786z']
# ----------------------------------------
# [208, 'Begusarai construction ka pariyojna ka aur Mokama pariyojna ka', '@riteshkumar-pi6mv']
# ----------------------------------------
# [209, 'EDFC ka apdet do bhai 🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🇮🇳🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉🎉', '@mastinews4687']
# ----------------------------------------
# [210, 'i am from patna.. this drone view is amazing 😍', '@mathurrk.']
# ----------------------------------------
# [211, 'Thanks for sharing ❤', '@shresthkumar1499']
# ----------------------------------------
# [212, 'I know u have a busy schedule. But there are 7 underground metro station under construction in only red line. Blue line start soon.', '@indrajeetkumar0136']
# ----------------------------------------
# [213, 'You skip the more underground metro station like Patna university metro station, moin ul haq and pmch. And also you should know that , first tbm launched in moin ul stadium metro station.', '@indrajeetkumar0136']
# ----------------------------------------
# [214, '❤❤', '@vishaldrives6432']
# ----------------------------------------
# [215, 'Bhai,😮 Bihar Mausam  Aur Patna taramandal jarur dekh ke jana bahut achha bana ha❤❤❤', '@PradeepKumar-ke1sr']
# ----------------------------------------
# [216, 'Valmikinagar, bihar mein valmiki sabhagar bn rha hai 95% kaam ho chuka hai…please uspe video bnaiye', '@RakeshKumar-wr9ij']
# ----------------------------------------
# [217, 'Thanks to visit my town... Again to coverage of कंस्ट्रक्शन वर्क of patna metro....', '@DharmendraKumar-mt8xn']
# ----------------------------------------
# [218, 'Sir plese Nath corridor bareilly ka update do plese', '@BrainBox270']
# ----------------------------------------
# [219, 'Bagmpul rrts station or meerut metro ka update do', '@Middle_boy345']
# ----------------------------------------
# [220, 'Rajendra nagar junction nhi Terminal hai bhai 😂😂😂', '@himanshuraj291']
# ----------------------------------------
# [221, 'Kuch kaam hi ni hua😂', '@Manan.0203']
# ----------------------------------------
# [222, 'आप का सभी विडियो देखता हूं अच्छा लगा ❤', '@maheshdubey8715']
# ----------------------------------------
# [223, 'Pls show rrts Delhi update', '@abhinavisgod8975']
# ----------------------------------------
# [224, 'Finally bihar get metro <br><br>And also you are the best person', '@botplayed163']
# ----------------------------------------
# [225, 'Thanks for updating Bihar metro project ❤', '@Mahi_mar_rha_hai_07']
# ----------------------------------------
# [226, 'Bhaiya meerut side begum pull ka bhi bata do', '@princesaini3204']
# ----------------------------------------
# [227, 'Thanks for updating our bihar ❤❤', '@pranavraj9914']
# ----------------------------------------
# [228, 'First viewer this video 😊😊', '@princesaini3204']
# ----------------------------------------
# [229, 'Best update bhi', '@botplayed163']
# ----------------------------------------
# [230, 'First', '@aromal.a.p7647']
# ----------------------------------------
# Comments have been saved to youtube_comments.csv

# %%
# Function to Clean Comments
def clean_comment(comment):
    comment = re.sub(r'http\S+', '', comment)  # Remove URLs
    comment = re.sub(r'[^A-Za-z0-9\s]', '', comment)  # Remove special characters
    comment = comment.strip()  # Remove leading and trailing whitespace
    comment = comment.lower()  # Convert to lowercase
    return comment

# %%
# # Function to Convert Emojis to Placeholder Text
# def convert_emojis(comment):
#     # Replace emojis with a placeholder text
#     return re.sub(r'[^\x00-\x7F]+', '[EMOJI]', comment)

# %%
# Function to Tokenize Comments
def tokenize_comment(comment):
    return word_tokenize(comment)

# %%
# Function to Remove Stopwords
stop_words = set(stopwords.words('english'))

def remove_stopwords(tokens):
    return [word for word in tokens if word not in stop_words]

# Function to Lemmatize Tokens
lemmatizer = WordNetLemmatizer()

def lemmatize_tokens(tokens):
    return [lemmatizer.lemmatize(word) for word in tokens]

# Function to Detect Language
def detect_language(comment):
    try:
        return detect(comment)
    except LangDetectException:
        return "unknown"  # Return 'unknown' if the language cannot be detected

# Function to Translate Comments to English
translator = Translator()

def translate_comment(comment, target_lang='en'):
    try:
        translated = translator.translate(comment, dest=target_lang)
        return translated.text
    except Exception as e:
        return comment  # Return the original comment if translation fails

# %%
# Perform Data Preprocessing
def preprocess_data(df):
    df['cleaned_comment'] = df['Comment'].apply(clean_comment)
    print("\nData after Cleaning:")
    print(df[['Comment', 'cleaned_comment']].head())


    # df['tokenized_comment'] = df['emoji_converted_comment'].apply(tokenize_comment)
    # print("\nData after Tokenization:")
    # print(df[['emoji_converted_comment', 'tokenized_comment']].head())

    # df['filtered_comment'] = df['tokenized_comment'].apply(remove_stopwords)
    # print("\nData after Stopwords Removal:")
    # print(df[['tokenized_comment', 'filtered_comment']].head())

    # df['lemmatized_comment'] = df['filtered_comment'].apply(lemmatize_tokens)
    # print("\nData after Lemmatization:")
    # print(df[['filtered_comment', 'lemmatized_comment']].head())

    # df['language'] = df['lemmatized_comment'].apply(lambda x: detect_language(' '.join(x)))
    # print("\nDetected Languages:")
    # print(df[['lemmatized_comment', 'language']].head())

    # df['translated_comment'] = df.apply(lambda row: translate_comment(' '.join(row['lemmatized_comment'])) if row['language'] != 'en' else ' '.join(row['lemmatized_comment']), axis=1)
    # print("\nData after Translation (if applicable):")
    # print(df[['lemmatized_comment', 'translated_comment']].head())

    # df['sentiment'] = df['translated_comment'].apply(analyze_sentiment)
    # print("\nSentiment Analysis Results:")
    # print(df[['translated_comment', 'sentiment']].head())

    return df

# %%
df = pd.read_csv('youtube_comments.csv')
df = preprocess_data(df)
# Out:
# Data after Cleaning:
#                                              Comment  \
# 0                                         Nice video
# 1  Bihta airport ka bhi progress report dikhana h...
# 2  Bhai patna bachao tree lagao video me per ki b...
# 3  10 sal se metro banna raha hai Gujarat ke anda...
# 4                                        ❤❤❤❤❤❤❤🎉🎉🎉🎉
#
#                                      cleaned_comment
# 0                                         nice video
# 1  bihta airport ka bhi progress report dikhana h...
# 2  bhai patna bachao tree lagao video me per ki b...
# 3  10 sal se metro banna raha hai gujarat ke anda...
# 4
